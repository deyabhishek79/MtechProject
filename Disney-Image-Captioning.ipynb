# %% [markdown]
# <a href="https://colab.research.google.com/github/deyabhishek79/MtechProject/blob/main/Disney-Image-Captioning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from os import listdir
from pickle import dump
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.layers import Input, Reshape, Concatenate
import numpy as np
import string
import glob
from tensorflow.keras.models import Model

# %%
# load an image from filepath
def load_image(path):
    img = load_img(path, target_size=(224,224))
    img = img_to_array(img)
    img = np.expand_dims(img, axis=0)
    img = preprocess_input(img)
    return np.asarray(img)

# %%
# extract features from each photo in the directory
def extract_features(directory,is_attention=False):
  # load the model
  if is_attention:
    model = VGG16()
    model.layers.pop()
    # extract final 49x512 conv layer for context vectors
    final_conv = Reshape([49,512])(model.layers[-4].output)
    model = Model(inputs=model.inputs, outputs=final_conv)
    print(model.summary())
    features = dict()
  else:
    model = VGG16()
    # re-structure the model
    model.layers.pop()
    model = Model(inputs=model.inputs, outputs=model.layers[-1].output)
    print(model.summary())
    # extract features from each photo
    features = dict()

  for name in glob.glob(directory):
    # ignore README
    if name == 'README.md':
      continue
    filename = name
    image = load_image(filename)
    # extract features
    feature = model.predict(image, verbose=0)
    # get image id
    image_id = name.split('.')[0]
    # store feature
    features[image_id] = feature
    print('>%s' % name)
  return features

# %%
# load doc into memory
def load_doc(filename):
  # open the file as read only
  file = open(filename, 'r')
  # read all text
  text = file.read()
  # close the file
  file.close()
  return text

# %%
# extract descriptions for images
def load_descriptions(doc):
  mapping = dict()
  # process lines
  for line in doc.split('\n'):
    # split line by white space
    tokens = line.split()
    if len(line) < 2:
      continue
    # take the first token as the image id, the rest as the description
    image_id, image_desc = tokens[0], tokens[1:]
    # remove filename from image id
    image_id = image_id.split('.')[0]
    # convert description tokens back to string
    image_desc = ' '.join(image_desc)
    # create the list if needed
    if image_id not in mapping:
      mapping[image_id] = list()
    # store description
    mapping[image_id].append(image_desc)
  return mapping

# %%
def clean_descriptions(descriptions):
  # prepare translation table for removing punctuation
  table = str.maketrans('', '', string.punctuation)
  for key, desc_list in descriptions.items():
    for i in range(len(desc_list)):
      desc = desc_list[i]
      # tokenize
      desc = desc.split()
      # convert to lower case
      desc = [word.lower() for word in desc]
      # remove punctuation from each token
      desc = [w.translate(table) for w in desc]
      # remove hanging 's' and 'a'
      desc = [word for word in desc if len(word)>1]
      # remove tokens with numbers in them
      desc = [word for word in desc if word.isalpha()]
      # store as string
      desc_list[i] =  ' '.join(desc)

# %%
# convert the loaded descriptions into a vocabulary of words
def to_vocabulary(descriptions):
  # build a list of all description strings
  all_desc = set()
  for key in descriptions.keys():
    [all_desc.update(d.split()) for d in descriptions[key]]
  return all_desc

# %%
# save descriptions to file, one per line
def save_descriptions(descriptions, filename):
  lines = list()
  for key, desc_list in descriptions.items():
    for desc in desc_list:
      lines.append(key + ' ' + desc)
  data = '\n'.join(lines)
  file = open(filename, 'w')
  file.write(data)
  file.close()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# extract features from all images

directory = '/content/drive/MyDrive/Images_Dataset_temp/*jpg'
features = extract_features(directory)
print('Extracted Features: %d' % len(features))
# save to file
dump(features, open('/content/drive/MyDrive/Images_Dataset_temp/features.pkl', 'wb'))
# Out:
# Streaming output truncated to the last 5000 lines.
# >/content/drive/MyDrive/Images_Dataset_temp/3138562460_44227a35cf.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2969380952_9f1eb7f93b.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3358682439_be4b83544c.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/447722389_4b51b7e13d.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3516299821_8f0375d221.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2891240104_6755281868.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/508958120_afe274f726.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/333973142_abcd151002.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2374247382_023a86b9ca.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3626642428_3396568c3c.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3412450683_7da035f2de.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2260649048_ae45d17e68.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2043427251_83b746da8e.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3425756814_13909354d4.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3366904106_e996320d20.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/1405221276_21634dcd58.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2778290592_1910bb0431.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2232518012_8cb0bbc43b.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3316046339_8e504be038.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2945036454_280fa5b29f.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/282116218_7fd7583d6e.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/271660510_dd4ba34b35.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2836325261_a3bf5c59be.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2842609837_b3a0b383f7.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3205214191_29b42b9b09.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3293596075_973b0bfd08.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3088074124_481139dc92.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/970641406_9a20ee636a.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2074244690_82e30ff44b.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3546891929_f31a99cd0d.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/836828001_af98d16256.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2196050115_e236d91f52.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3457460673_800d7f7dd9.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/55470226_52ff517151.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/1478268555_7e301fc510.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2100909581_b7dde5b704.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2940366012_1ef8ab334e.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3043904009_3b5e0412cd.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/1459250022_bf1eddad11.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2701042060_92508ea8fa.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/458004873_f084c47a88.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3058439373_9276a4702a.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2887744223_029f2fd5fe.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/1459032057_97e73ed6ab.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3516653997_98ec551a67.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3419238351_ac18b440c0.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/940973925_a2e6d7951c.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/1160034462_16b38174fe.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2565618804_8d7ed87389.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3375920709_ef7370fa09.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/415657941_454d370721.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/293879742_5fe0ffd894.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2902486045_6298eb22ef.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3494345896_dd6b32cfa3.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3767841911_6678052eb6.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/241345942_ea76966542.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2533414541_362bf043bb.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2923825744_ca125353f0.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3256456935_664a7a5bba.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2268601066_b018b124fd.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2508313118_524e93d48c.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3099264059_21653e2536.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3425851292_de92a072ee.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3487979741_5f244c0c4b.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2713897716_c8cd610360.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/496380034_d22aeeedb3.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3073535022_4af81f360c.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/219070971_ae43410b9e.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/492493570_c27237a396.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3332467180_d72f9b067d.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3056530884_27766059bc.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3559374748_f18c7caa55.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3694093650_547259731e.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/426065353_e9a604a01f.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/124195430_d14028660f.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3636055584_65a60426f8.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2797438951_88a3ed7541.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2243904502_2d265fed80.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/260162669_c79a900afb.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/381514859_b40418d9c3.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3738685861_8dfff28760.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2393911878_68afe6e6c1.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2727051596_be65bfb3d3.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3258394043_a0b6a94dce.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2516317118_10ae66b87a.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3650111717_346804ec2f.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3111482098_11c0f4f309.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2891961886_b7a2f0b0fd.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2943384009_c8cf749181.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2057306459_2f52ce648e.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3263497678_8bb688ca01.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3206058778_7053ee6b52.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3553225222_f5ebe44af1.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3590294974_4ef98f013e.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2244551043_21b8cca866.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3670075789_92ea9a183a.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/754852108_72f80d421f.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2195620255_6693479734.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/516394876_8b9b8021bc.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2938875913_0ed920a6be.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3523819210_99782628fc.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3207676216_48478bce97.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3166366760_e43cf66eda.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2920305300_a5b1b2329a.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/489372715_ce52da796a.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/1015118661_980735411b.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3476451861_5b9c9ce191.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3319723910_af5b5f1fae.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3410902181_b2a3c6eec9.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3413571342_b9855795e2.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2206960564_325ed0c7ae.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3298175192_bbef524ddc.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3198247669_7493af04a7.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2984174290_a915748d77.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2893476169_f38dd32051.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3597354819_0069aaf16e.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3442138291_3e75f4bdb8.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2471493912_2d4746b834.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/709373049_15b8b6457a.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/292780636_72e1968949.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3508522093_51f6d77f45.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3360994630_d4616c1b14.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3357194782_c261bb6cbf.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3530087422_7eb2b2c289.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/241031254_0c6f30e3d1.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3504940491_94c43792ed.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2911658792_6a6ef07e3a.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3705976184_53ae07e898.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3600221224_945df01247.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/1563731247_7f21d8bec0.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3550276904_19de3561c5.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3427402225_234d712eeb.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3301021288_95935b7a74.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3189941492_a3f4347b1a.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3396251819_1efa69310f.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2652155912_8ba5426790.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/241346434_0527ea1c07.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2004674713_2883e63c67.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3577235421_69e4efb8d1.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3649307685_60c1294d2a.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2704934519_457dc38986.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/697582336_601462e052.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2866974237_e3c1e267c0.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2935986346_29df6cf692.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2298283771_fb21a4217e.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3475092236_cf45d383c7.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/707941195_4386109029.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/417577408_eb571658c1.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2355880294_8f78a6fea6.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3657016761_d553e514d9.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/262963190_a78b799e89.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2039457436_fc30f5e1ce.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3508637029_89f3bdd3a2.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/247691240_3881777ab8.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2917843040_7c9caaaa8a.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/295258727_eaf75e0887.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2436398074_8737f40869.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3687222696_85bf6f78f7.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/268365231_a0acecdc45.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2337757064_08c4033824.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3517362674_0f5296de19.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3398745929_8cd3bbb8a8.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2707873672_15e6b5d54b.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3522000960_47415c3890.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3636491114_ab34dac833.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2942094037_f6b36fd3db.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2939371251_f923569a72.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3323498985_fd9d2803fd.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2623560640_0445c9a138 (1).jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3545427060_c16a8b7dfd.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3299418821_21531b5b3c.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2511019188_ca71775f2d.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3113769557_9edbb8275c.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3183875944_b2be694e06.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3347701468_bb0001b035.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2623560640_0445c9a138.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2640000969_b5404a5143.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3589368949_0866846949.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2358898017_24496b80e8.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2568417021_afa68423e5.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3146937399_8c046b7b1a.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3192069971_83c5a90b4c.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3086523890_fd9394af8b (1).jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3513265399_a32e8cfd18.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2364394224_c17b09e035.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2657301826_aab4c36e6c.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3086523890_fd9394af8b.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2981372647_2061278c60.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3115901702_f07aa0ef74.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2414397449_2ac3b78e0d.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/460781612_6815c74d37.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3219122000_bd6b4ae5ff.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3104400277_1524e4f758.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/539801139_7258ee437f.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2351479551_e8820a1ff3.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3454621502_73af6742fb.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2909811789_ed8f3fd972.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3009018821_ba47396e24.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3685373706_37f2ced9ff.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3625049113_554d82c2a1.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3014169370_fc4059352e.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3375134059_7e9eb2ef01.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/799486353_f665d7b0f0.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/527288854_f26127b770.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3046429283_08de594901.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2257798999_d9d1b9a45a.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2107837987_ffecfc367a.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/1508269285_6c5723f67d.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2623247254_3bfc795121.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/397982550_cf9f5cdb74.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/1022454332_6af2c1449a.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3453313865_1ebff5393c.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2968182121_b3b491df85.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3701878677_8f2c26227b.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3648160673_0c783236a6.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3297272270_285b8878b2.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3165750962_e2e3843679.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3170856184_efabfd0297.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2831313661_1a328acb70.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2800004913_c8394ba332.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/1245022983_fb329886dd.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2914206497_5e36ac6324.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3338291921_fe7ae0c8f8.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3517124784_4b4eb62a7a.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3255482333_5bcee79f7e.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3596131692_91b8a05606.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/1167908324_8caab45e15.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2090545563_a4e66ec76b.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3197891333_b1b0fd1702.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3518608016_46453d8b18.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2648165716_02e2e74fd6.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3088322308_b0c940b3a3.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/512026551_ba63ddbd31.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2607130765_97833d6ce1.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3073579130_7c95d16a7f.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3325578605_afa7f662ec.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2267819545_446c5a3e18.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3016200560_5bf8a70797.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3423249426_02bedf9260.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2877637572_641cd29901.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/582788646_dc40748639.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2085255128_61224cc47f.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3573202338_f43dd22d28.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2656890977_7a9f0e4138.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/846085364_fc9d23df46.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2064790732_219e52e19c.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3116769029_f5a76f04ba.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3475005101_6f6e437459.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3724581378_41049da264.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3507670136_2e5f94accf.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3153828367_5fc2c37c07.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3165826902_6bf9c4bdb2.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/1453366750_6e8cf601bf.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2887750774_920eb171aa.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2303356248_65dd6aba6f.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2125454445_5c5c4bf906.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2089350172_dc2cf9fcf6.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/566384456_97da3c7bd6.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3279988814_d3693dcb6c.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3174726084_c108de0a64.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3436395540_63bc8f2fe0.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2061927950_dafba5b8a3.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/197107117_4b438b1872.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2923497185_c64004ff2d.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/124972799_de706b6d0b.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2519594430_551225e5bd.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3443460885_46115463b4.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3606355203_1260f43ec0.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3134341610_3c55e373a7.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3106340185_80d0cb770a.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/365759754_6cf7068c9a.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3639967449_137f48b43d.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/143552697_af27e9acf5.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2666205903_8d287669e1.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3415311628_c220a65762.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/1357724865_4faf4e1418.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2856524322_1d04452a21.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2599131872_65789d86d5.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2718376488_3c62f7642c.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3333921867_6cc7d7c73d.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2116316160_d5fa7abdc3.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2557129157_074a5a3128.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3578477508_b7d839da16.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/506367606_7cca2bba9b.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3349451628_4249a21c8f.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/977856234_0d9caee7b2.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/1597319381_1e80d9e39c.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3123770450_cedc16d162.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3185695861_86152b2755.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/210686241_b8e069fff3.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2461616306_3ee7ac1b4b.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3086810882_94036f4475.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/1149179852_acad4d7300.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3565021218_d2bc1aa644.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3027399066_ca85495775.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2255338013_566127590b.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2092177624_13ab757e8b.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3184112120_6ddcd98016.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2115631346_9585a479b0.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3395173129_f0ac0a1ed4.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2272750492_91e8f67328.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2085557551_7a88d01d4e.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3555573680_41c1540a86.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/241374292_11e3198daa.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2609836649_b55831ed41.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3613175012_bcd063e7c9.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3339105374_cc41e0b7d7.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2218743570_9d6614c51c.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2802337003_56e555cd30.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2909875716_25c8652614.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2861932486_52befd8592.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/1818403842_553a2a392c.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2246717855_c0c08fe5d2.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2384401298_e389c01abc.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/407008823_bdd7fc6ed5.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2251418114_2b0cd4c139.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2029280005_a19609c81a.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2658009523_b49d611db8.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/488416045_1c6d903fe0.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3214579977_fa9fb006a6.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3117562746_62f57a02b5.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2254913901_569f568926.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2460159430_71ab1aacfa.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3426724811_137855b4f7.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3025315215_a5d367971a.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2123932281_1a4fd38455.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/1994416869_4dd769a806.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3294964868_16f4f9fa9d.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3417102649_5c0b2f4b4d.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2480832276_fa55480ecb.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2302747917_aa0300eb68.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3534512991_f9fd66f165.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3662963630_8f097e38d4.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/583087629_a09334e1fb.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/311619377_2ba3b36675.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3220009216_10f088185e.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3225478803_f7a9a41a1d.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3681651647_08eba60f89.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2077346067_0a3a5aae65.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2676937700_456134c7b5.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/1674612291_7154c5ab61.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2458269558_277012780d.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3264337159_e1680a35ba.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3203707977_cc9448fecb.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2616284322_b13e7c344e.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3665549027_d7fb05d157.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2677614492_792023b928.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3237760601_5334f3f3b5.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3495349745_1b29a63571.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3484365373_98d5304935.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2266144051_614b2d62b0.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/127490019_7c5c08cb11.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2219805467_370ee1b7aa.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/334768700_51c439b9ee.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/1356796100_b265479721.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2300229745_af7a20c959.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3086507638_d8a2cd0ac3.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2744600462_5804577296.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/1808370027_2088394eb4.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3227423095_5049951eab.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/837893113_81854e94e3.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2173677067_9d0732bcc2.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3646927481_5e0af1efab.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2517284816_9b8fd3c6b6.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2376878930_dd3e7cc544.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3425069551_aba046a1b6.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/482882307_7dcb9eee11.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3049649128_d83d847168 (1).jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2959737718_31203fddb5.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3106782647_b078830a9e.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3473534758_1ae3847781.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/539667015_fd0a3bea07.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2641770481_c98465ff35.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2980348138_91cc6f6d0f.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/279230262_e541f9b670.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2455528149_6c3477fd33.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/544257613_d9a1fea3f7.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/506478284_7cf8bdbe36.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2519812011_f85c3b5cb5.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3122579598_14841c038a.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3612249030_e2829ffa31.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3650986674_3e101c606b.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2876994989_a4ebbd8491.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3066338314_2c3fb731d1.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2987775031_3f9ac69319 (1).jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3030823649_3b7b6c728d.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2286823363_7d554ea740.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2774554310_007e980a90.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/317383917_d8bfa350b6.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3224227640_31865b3651.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2987775031_3f9ac69319.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3126752627_dc2d6674da.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/1523800748_a59e980eee.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3454149297_01454a2554.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2766291711_4e13a2b594.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3323514651_3efdbd63ed.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2119302248_72493d458c.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2275029674_6d4891c20e.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3677514746_26f5588150.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/244774022_a12c07afdb.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3139160252_75109e9e05.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3181701312_70a379ab6e.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/317641829_ab2607a6c0.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3029463004_c2d2c8f404.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/1131340021_83f46b150a.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/416960865_048fd3f294.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3549277110_24d4064ccd.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3370085095_6abbb67c1d.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3181409177_edb09c2718.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3235076435_1eaa40bd0a.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3418504074_083f0bb68d.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2570559405_dc93007f76.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3653764864_225958c9c1.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2936707421_8e629874b8.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3147758035_e8a70818cb.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3640443200_b8066f37f6.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2473689180_e9d8fd656a.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/519061891_320061864e.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3330675488_8692476a4a.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/292887910_f34ac101c8.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2659554389_ed3d15093f.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/1296412797_85b6d2f8d6.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3417231408_6ce951c011.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3330654550_3efe9a71af.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2910758605_73a3f5a5c2.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3687996279_05b5a2a706.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3441511444_b031585b45.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3074842262_62b1b2168c.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3180806542_49b6de312d.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/512031915_0dd03dcdf9.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2886411666_72d8b12ce4.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2755952680_68a0a1fa42.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3097171315_0ba7d283b1.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3377344932_6dfce93248.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2705947033_5999147842.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2772532341_c4597a94ed.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3019842612_8501c1791e.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/1965278563_8279e408de.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/270816949_ffad112278.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/1947351225_288d788983.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3014986976_0e7b858970.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3420323191_d66e003264.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2287023569_fd7a9c60b8.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3256603992_67312b5a36.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2208067635_39a03834ca.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/866841633_05d273b96d.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2959500257_3621429a37.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3247341210_5d1e50df23.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2596619849_7b635dd310.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3551787566_b5ebbe2440.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/308307853_5a51fbdecc.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3229913073_e7857a5966.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2354540393_a149722680.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2060031241_a3ae7a06bb.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2631625732_75b714e685.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/475042270_719ebe6c48.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3386060324_b98fdfa449.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3638440337_6d5c19a8f0.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3559781965_d4ec00e506.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3672940355_47f30e2b28.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2877159456_ea4a46b0d2.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2481598514_05a65d1f72.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3527926597_45af299eee.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/313051099_1bb87d6c56.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3384314832_dffc944152.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/1107246521_d16a476380.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3049649128_d83d847168.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3590653633_495de5f288.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2477623312_58e8e8c8af.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2808098783_c56b44befa.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/479807465_cf42f39d00.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/272546805_536c719648.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2710698257_2e4ca8dd44.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2899276965_a20b839cfd.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3195701071_81879257f5.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/233270519_d60d4518fa.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/366713533_bd6d48cf02 (1).jpg
# >/content/drive/MyDrive/Images_Dataset_temp/366713533_bd6d48cf02.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/109202801_c6381eef15.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/1449625950_fc9a8d02d9.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/756909515_a416161656.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3321516504_5ee97771cb.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2649406158_ded6be38de.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/556568556_bc5124dc8e.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/743571049_68080e8751.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/1417882092_c94c251eb3.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3197981073_3156963446.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2990471798_73c50c76fb.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2612040125_0a93889f06.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2362481035_a7600875d0.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3571193625_835da90c5e.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3613955682_3860e116cf.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2211593099_4a4f1c85d2.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3590557969_d0270d518b.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3108544687_c7115823f5.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2021671653_567395c7cf.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3139118874_599b30b116.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/1280320287_b2a4b9b7bd.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2752341621_54490b9b09.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3502459991_fdec2da131.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3175849727_bf30b892cb.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2320125735_27fe729948.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/1163282319_b729b24c46.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3605676864_0fb491267e.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3357708906_fb3a54dd78.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2929006980_9f9f8f3d21.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2747714500_49476225c6.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/1781227288_6811e734be.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3562050678_4196a7fff3.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3759492488_592cd78ed1.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3080056515_3013830309.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/428796930_476a3d6395.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3207343907_995f7ac1d2.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/262446581_06ef7d9445.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2273038287_3004a72a34.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/1685990174_09c4fb7df8.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3402081035_a54cfab1d9.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/757133580_ba974ef649.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3278811919_d5a3432af6.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2867736861_43c9487a65.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3406116788_c8f62e32d1.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2085726719_a57a75dbe5.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2151056407_c9c09b0a02.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/1348947380_14f0fc1237.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/432248727_e7b623adbf.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/421932359_edbf181f44.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3373544964_c9f1253b7d.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2209888959_d636b1be0b.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3551447084_becc6a4666.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/1335617803_4fbc03dab0.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3132006797_04822b5866.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2165677531_e1d5e086f7.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/820169182_f5e78d7d19.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3517127930_5dbddb45f6.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2787276494_82703f570a.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2985439112_8a3b77d5c9.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2219959872_988e6d498e.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2663794355_e726ec7e05.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3600909823_ce72c26e66.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/1082379191_ec1e53f996.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2998861375_02817e0147.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2739332078_13d9acce59.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3174713468_e22fa7779e.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2090327868_9f99e2740d.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2730994020_64ac1d18be.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2847615962_c330bded6e.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3726170067_094cc1b7e5.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3016178284_ec50a09e8c.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3109136206_f7d201b368.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3109268897_d43797fc6a.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3033825101_44a4390f16.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/400851260_5911898657.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2949353587_64c54e9589.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2284239186_c827f4defa.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3553374585_25b1bd6970.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2878578240_caf64c3b19.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/753285176_f21a2b984d.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/887108308_2da97f15ef.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3157220149_cc3c8cc84d.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/226607225_44d696db6b.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2215165918_2bf5b659dd.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3674521435_89ff681074.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/200771289_31902164a7.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/537225246_dd0e2158a7.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2535746605_8124bf4e4f.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/534313000_4ad39c7ee0.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3509575615_653cbf01fc.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3472270112_0a7cb7b27c.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/240696675_7d05193aa0.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/293151893_ee7249eccb.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3082934678_58534e9d2c.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3125628091_25a31709df.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/111537222_07e56d5a30.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3174431688_ae84778db0.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3403263046_3cc701a07a.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/251958970_fa6b423f23.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/300500054_56653bf217.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3086526292_f799d237c7.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2687529141_edee32649e.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2711720095_0b98426d3c.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2895700779_fac1d9d278.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3635991166_f95304af0a.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2578395598_6982734d46.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2114126343_a0f74ff63b.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/278388986_78ba84eb8f.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3107592525_0bcd00777e.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2496236371_61dec88113.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3466891862_9afde75568.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2094543127_46d2f1fedf.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3665569615_9a71c4b6e4.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/515755283_8f890b3207.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3335097235_538f4777c3.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3655964639_21e76383d0.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3109780402_dbae082dc5.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/1131800850_89c7ffd477.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/1141718391_24164bf1b1.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/267015208_d80b3eb94d.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2414384480_096867d695.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/1303548017_47de590273.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2838085973_42b6e9b5b1.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3260191163_6c1551eee8.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/339658315_fbb178c252.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3695949492_27ca3892fd.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3429194423_98e911a101.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/189740668_0b045f1ff2.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2269021076_cefc9af989.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3503544012_1771be9d3a.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/186890605_ddff5b694e.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3270047169_2ed289a9af.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/1317292658_ba29330a0b.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2497074804_b4f3e7fd90.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2938747424_64e64784f0.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/1481062342_d9e34366c4.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3726025663_e7d35d23f6.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3638992163_a085cc0c24.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3490867290_13bcd3a7f0.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3164423279_9b27cb6a06.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/397815951_3b02090324.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3105315670_5f86f73753.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3570800810_978c993133.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2495394666_2ef6c37519.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3209350613_eb86579ee8.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2052202553_373dad145b.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3439414478_8038ba9409.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2830880811_d7f66dd2cf.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2930318834_8366811283.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/380034515_4fbdfa6b26.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3532539748_795d16ef07.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3100251515_c68027cc22.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3234719720_5bb2fc5ffa.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3514188115_f51932ae5d.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/374103966_2987706be1.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3018847610_0bf4d7e43d.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2782850287_1408f7ec43.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2281006675_fde04e93dd.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2496370758_a3fbc49837.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2587017287_888c811b5a.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2814037463_74de97da86.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2498897831_0bbb5d5b51.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2689001252_e0016c89f0.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/190638179_be9da86589.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/527968666_1fcddf81ab.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/911795495_342bb15b97.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2180886307_5156460b2c.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3305767464_d64a336f60.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/374828031_9d087da5cf.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3033612929_764d977bd5.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3609032038_005c789f64.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2404520067_87798dbaee.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2083778090_3aecaa11cc.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/244571201_0339d8e8d1.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2102581664_5ea50f85c6.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/470887791_86d5a08a38.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3640870001_acbd1d5ceb.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/531055369_936fd76a63.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/289860281_94d699f36d.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2588927489_f4da2f11ec.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2340919359_f56787d307.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3220126881_b0a4f7cccb.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/1432179046_8e3d75cf81.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2098646162_e3b3bbf14c.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3477315700_52a4d740a5.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/1362128028_8422d53dc4.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/990890291_afc72be141.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3070485870_eab1a75c6f.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2165461920_1a4144eb2b.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/747242766_afdc9cb2ba.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/542317719_ed4dd95dc2.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2061397486_53a61e17c5.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/247618600_239eeac405.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3432656291_a6c7981f6e.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3373243733_9aba7740ed.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3409740108_1505489537.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2831578193_3c997ae330.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3724623861_2bb6c23641.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/400562847_e15aba0aac.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2091171488_c8512fec76.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/489134459_1b3f46fc03.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3323076458_3ce72a1dae.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/862177617_c2c0581075.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/1821238649_2fda79d6d7.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/241347823_6b25c3e58e.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2362377137_9528692825.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/611910909_4f8e43e070.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2541104331_a2d65cfa54.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/427082246_5bf1c3676f.jpg
# ...
# >/content/drive/MyDrive/Images_Dataset_temp/2144846312_d4c738dc6c.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/485357535_b45ba5b6da.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3439560988_f001f96fc9.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/534056823_0752303702.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3222041930_f642f49d28.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3404978479_8a81843e17.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/565605894_8f0bed0438.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3178371973_60c6b8f110.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3027397797_4f1d305ced.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/398413603_166896900f.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2555521861_fc36fd3ab0.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3333017828_b930b9d41b.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3662406028_29b9e46a6f.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/440737340_5af34ca9cf.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3257182199_5fda78d870.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3425835357_204e620a66.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2272489996_95b0a62d15.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2895966469_53e0b29295.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3683185795_704f445bf4.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/571507143_be346225b7.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3657209354_cde9bbd2c5.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/235074044_c1358888ed.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/1105959054_9c3a738096.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3171347658_f0d5469c56.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/624058168_f1c5e87e59.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/1501985304_8c50093004.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3694555931_7807db2fb4.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2444935470_7b0226b756.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2897832422_0cbdb1421e.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/1295698260_e10c53c137.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3358380484_b99b48f0c9.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2851198725_37b6027625.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3518675890_2f65e23ff9.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2074146683_7c83167aa1.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3338590946_f25b76cbc7.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3758175529_81941e7cc9.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3543378438_47e2712486.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2395967330_7e6ea404f6.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2660480624_45f88b3022.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3144705706_391d7b77c7.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3247693965_845b3b4349.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3613323772_d15cef66d1.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3048461682_e89f81b1c7.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3146630574_05d9ebbed1.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2068465241_3bcabacfd7 (1).jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2748729903_3c7c920c4d.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/656260720_a7db4ce48b.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/497791037_93499238d8.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2317714088_bcd081f926.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2068465241_3bcabacfd7.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3433982387_3fa993cf5a.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3539840291_1c3eed701d.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2687672606_275169c35d.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3353400143_8b9543f7dc.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3638783842_af08dbb518.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3271385712_ffd34f2de5.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3066429707_842e50b8f7.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/118309463_a532b75be9.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2480850054_de3433b54a.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3677734351_63d60844cb.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/241346402_5c070a0c6d.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3085667767_66041b202e.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2335428699_4eba9b6245.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/824923476_d85edce294.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/42637986_135a9786a6.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/1433088025_bce2cb69f8.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3468130925_2b1489d19a.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2140182410_8e2a06fbda.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3123463486_f5b36a3624.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3499720588_c32590108e.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3332202255_a30c522664.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3613667665_1881c689ea.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3621329299_6fb3f2935c.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/488356951_b3b77ad832.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3593538248_dffa1a5ed4.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/1357689954_72588dfdc4.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/540604040_bec822c144.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2851304910_b5721199bc.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3149804151_1cc8d10783.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3638783120_f600ceb19d.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3679341667_936769fd0c.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2528521798_fb689eba8d.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3640241166_b1ab7a8e7a.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3432586199_e50b0d6cb7.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3121521593_18f0ec14f7.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3501313414_ae865b6fdf.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/468911753_cc595f5da0.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2622971954_59f192922d.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2297471897_3419605c16.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3334300164_e75e0479ae.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3342309960_c694b2cce9.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2845246160_d0d1bbd6f0.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2892467862_52a3c67418.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2873837796_543e415e98.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3353328134_dd9ed0edab (1).jpg
# >/content/drive/MyDrive/Images_Dataset_temp/534200447_b0f3ff02be.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3408274796_0dc62225e9.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2339573065_91f1e3be60.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2339946012_06bd480ab8.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/357191373_a1cb5696e8.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3308018795_68a97a425c.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3132760860_3e743a935d.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2698614194_b4e6e11dff.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3375070563_3c290a7991.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3319058642_885d756295.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3689355450_fd559b816d.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3591458156_f1a9a33918.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3677302645_8cd3fac70d.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3493255026_5fdaa52cbe.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/1572286502_64e5c4b920.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2297744130_f571f3a239.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3157039116_d82da4e66b.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3553056438_4e611a7a2a.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3081363964_d404eccae8.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3223606402_bb2aa6db95.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/1000268201_693b08cb0e.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3262475923_f1f77fcd9f.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/516725192_c9cdd63878.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2704257993_d485058a5f.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2876494009_9f96d7eaf2.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2561481438_447b852e4d.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2525270674_4ab536e7ec.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/491564019_1ca68d16c1.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3303797949_339bb969ba.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3620492762_7f6a9b4746.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3587077732_0933f1677b.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3350786891_6d39b234e9.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3682038869_585075b5ff.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3644941648_012ec87848.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3579686259_b1fe6aefc9.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/479807115_3a484fb18b.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2814028429_561a215259.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3500399969_f54ce5848f.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3353328134_dd9ed0edab.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3084034954_fe5737197d.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2636514498_01fcc5f501.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3474406285_01f3d24b71.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3663951804_868982f3f9.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/410453140_5401bf659a.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/778885185_3f6905370b.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3376972502_35e3e119cd.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3250589803_3f440ba781.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3319388517_5609ae9805.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/751109943_2a7f8e117f.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/1129704496_4a61441f2c.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/799431781_65dc312afc.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2319197581_94f807b204 (1).jpg
# >/content/drive/MyDrive/Images_Dataset_temp/53043785_c468d6f931.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/1573017288_4d481856e2.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2278776373_fe499a93be.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/1562392511_522a26063b.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3451984463_37ac1ff7a8.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2353102255_67d9d2e40a.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3525841965_7814484515.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2950393735_9969c4ec59.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3757598567_739b7da835.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3708172446_4034ddc5f6.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/1803631090_05e07cc159.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2831215155_07ba8f1805.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/260850192_fd03ea26f1 (1).jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3068994801_b2bc079e67.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3647750811_395fbd397e.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3621717946_d96f8a6012.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/319847657_2c40e14113.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/424506167_01f365726b.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3060969260_08f43e4f4f.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2208055895_37cd8e1edf.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2521938720_911ac092f7.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/467960888_6943257534.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/265223843_9ef21e1872.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3676460610_8c52e8a355.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3730457171_e66dde8c91.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2992808092_5f677085b7.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2978409165_acc4f29a40.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2147199188_d2d70b88ec.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3320411267_df70b90501.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3415809168_af9dabdba5.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3582465732_78f77f34ae.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2500354186_0836309cc9.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3239480519_22540b5016.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2265100168_175f8218af.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3425061393_d093edb8da.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/1937262236_cbf5bfa101.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3334953664_a669038795.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3053785363_50392f2c53.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/1384292980_4022a7520c.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/260850192_fd03ea26f1.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/195962284_e57178054a.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/444872454_9f51e07f88.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/248858242_1c33c54ada.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2644916196_16f91dae54.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3421177332_a05741cfa4.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/1048710776_bb5b0a5c7c.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/1359101233_16c2c150e3.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3453284877_8866189055.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3681172959_6674c118d2.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3521374954_37371b49a4.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3294202771_e8ee78a439.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2425262733_afe0718276.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/385186343_464f5fc186.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/186346360_541047336f.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3535664885_c848c0faee.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/543940240_a54a3c7989.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2830755303_2b5444ab4c.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/57422853_b5f6366081.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2173312932_269f9786fc.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3084001782_41a848df4e.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2730938963_c4ed3e2258.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/347186933_880caaf53b.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3577309234_c952c2af86.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2319197581_94f807b204.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/191003287_2915c11d8e.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/404216567_75b50b5a36.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2199250692_a16b0c2ae1.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/1881494074_1bebd93089.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2178306830_6af49375b4.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/1490670858_e122df2560.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3518687038_964c523958.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3229282764_a4a515f4e2.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2867026654_38be983b44.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3273969811_42e9fa8f63.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2978810122_183e60ff2d.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2442243868_abe8f74fb4.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/3455419642_894d03f153.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/1295669416_21cabf594d.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2272491304_cb7c7ed16f.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/2274602044_b3d55df235.jpg
# >/content/drive/MyDrive/Images_Dataset_temp/435739506_2daf7f4887.jpg
# Extracted Features: 8144

# %%
# !pip install load_data
# Out:
# ERROR: Could not find a version that satisfies the requirement load_data (from versions: none)
# ERROR: No matching distribution found for load_data

# %%
import load_data as ld
import generate_model as gen
from tensorflow.keras.callbacks import ModelCheckpoint
from pickle import dump
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-25-d94141504383> in <module>()
# ----> 1 import load_data as ld
#       2 import generate_model as gen
#       3 from tensorflow.keras.callbacks import ModelCheckpoint
#       4 from pickle import dump
#
# ModuleNotFoundError: No module named 'load_data'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from pickle import load
import argparse

# load doc into memory
def load_doc(filename):
  # open the file as read only
  file = open(filename, 'r')
  # read all text
  text = file.read()
  # close the file
  file.close()
  return text

# load a pre-defined list of photo identifiers
def load_set(filename):
  doc = load_doc(filename)
  dataset = list()
  # process line by line
  for line in doc.split('\n'):
    # skip empty lines
    if len(line) < 1:
      continue
    # get the image identifier
    identifier = line.split('.')[0]
    dataset.append(identifier)
  return set(dataset)

# split a dataset into train/test elements
def train_test_split(dataset):
  # order keys so the split is consistent
  ordered = sorted(dataset)
  # return split dataset as two new sets
  return set(ordered[:100]), set(ordered[100:200])

# load clean descriptions into memory
def load_clean_descriptions(filename, dataset):
  # load document
  doc = load_doc(filename)
  descriptions = dict()
  for line in doc.split('\n'):
    # split line by white space
    tokens = line.split()
    # split id from description
    image_id, image_desc = tokens[0], tokens[1:]
    # skip images not in the set
    if image_id in dataset:
      # create list
      if image_id not in descriptions:
        descriptions[image_id] = list()
      # wrap description in tokens
      desc = 'startseq ' + ' '.join(image_desc) + ' endseq'
      # store
      descriptions[image_id].append(desc)
  return descriptions

# load photo features
def load_photo_features(filename, dataset):
  # load all features
  all_features = load(open(filename, 'rb'))
  # filter features
  features = {k: all_features[k] for k in dataset}
  return features

def prepare_dataset(data='dev'):

  assert data in ['dev', 'train', 'test']

  train_features = None
  train_descriptions = None

  if data == 'dev':
    # load dev set (1K)
    filename = 'Flickr8k_text/Flickr_8k.devImages.txt'
    dataset = load_set(filename)
    print('Dataset: %d' % len(dataset))

    # train-test split
    train, test = train_test_split(dataset)
    #print('Train=%d, Test=%d' % (len(train), len(test)))

    # descriptions
    train_descriptions = load_clean_descriptions('models/descriptions.txt', train)
    test_descriptions = load_clean_descriptions('models/descriptions.txt', test)
    print('Descriptions: train=%d, test=%d' % (len(train_descriptions), len(test_descriptions)))

    # photo features
    train_features = load_photo_features('models/features.pkl', train)
    test_features = load_photo_features('models/features.pkl', test)
    print('Photos: train=%d, test=%d' % (len(train_features), len(test_features)))

  elif data == 'train':
    # load training dataset (6K)
    filename = 'Flickr8k_text/Flickr_8k.trainImages.txt'
    train = load_set(filename)

    filename = 'Flickr8k_text/Flickr_8k.devImages.txt'
    test = load_set(filename)
    print('Dataset: %d' % len(train))

    # descriptions
    train_descriptions = load_clean_descriptions('models/descriptions.txt', train)
    test_descriptions = load_clean_descriptions('models/descriptions.txt', test)
    print('Descriptions: train=%d, test=%d' % (len(train_descriptions), len(test_descriptions)))

    # photo features
    train_features = load_photo_features('models/features.pkl', train)
    test_features = load_photo_features('models/features.pkl', test)
    print('Photos: train=%d, test=%d' % (len(train_features), len(test_features)))

  elif data == 'test':
    # load test set
    filename = 'Flickr8k_text/Flickr_8k.testImages.txt'
    test = load_set(filename)
    print('Dataset: %d' % len(test))
    # descriptions
    test_descriptions = load_clean_descriptions('models/descriptions.txt', test)
    print('Descriptions: test=%d' % len(test_descriptions))
    # photo features
    test_features = load_photo_features('models/features.pkl', test)
    print('Photos: test=%d' % len(test_features))

  return (train_features, train_descriptions), (test_features, test_descriptions)

if __name__ == '__main__':
  parser = argparse.ArgumentParser(description='Generate dataset features')
  parser.add_argument("-t", "--train", action='store_const', const='train',
    default = 'dev', help="Use large 6K training set")
  args = parser.parse_args()
  prepare_dataset(args.train)

# %%
def train_model(weight = None, epochs = 10):
  # load dataset
  data = ld.prepare_dataset('train')
  train_features, train_descriptions = data[0]
  test_features, test_descriptions = data[1]

  # prepare tokenizer
  tokenizer = gen.create_tokenizer(train_descriptions)
  # save the tokenizer
  dump(tokenizer, open('models/tokenizer.pkl', 'wb'))
  # index_word dict
  index_word = {v: k for k, v in tokenizer.word_index.items()}
  # save dict
  dump(index_word, open('models/index_word.pkl', 'wb'))

  vocab_size = len(tokenizer.word_index) + 1
  print('Vocabulary Size: %d' % vocab_size)

  # determine the maximum sequence length
  max_length = gen.max_length(train_descriptions)
  print('Description Length: %d' % max_length)

  # generate model
  model = gen.define_model(vocab_size, max_length)

  # Check if pre-trained weights to be used
  if weight != None:
    model.load_weights(weight)

  # define checkpoint callback
  filepath = 'models/model-ep{epoch:03d}-loss{loss:.3f}-val_loss{val_loss:.3f}.h5'
  checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1,
                save_best_only=True, mode='min')

  steps = len(train_descriptions)
  val_steps = len(test_descriptions)
  # create the data generator
  train_generator = gen.data_generator(train_descriptions, train_features, tokenizer, max_length)
  val_generator = gen.data_generator(test_descriptions, test_features, tokenizer, max_length)

  # fit model
  model.fit_generator(train_generator, epochs=epochs, steps_per_epoch=steps, verbose=1,
        callbacks=[checkpoint], validation_data=val_generator, validation_steps=val_steps)

  try:
      model.save('models/wholeModel.h5', overwrite=True)
      model.save_weights('models/weights.h5',overwrite=True)
  except:
      print("Error in saving model.")
  print("Training complete...\n")

if __name__ == '__main__':
    train_model(epochs=20)
